# %%
#install java if not already at 1.8
#sudo yum install java-1.8.0-openjdk.x86_64

# %%
# !clush -aB java -version
# Out:
# ---------------
# psnode[66-68] (3)
# ---------------
# openjdk version "1.8.0_161"
# OpenJDK Runtime Environment (build 1.8.0_161-b14)
# OpenJDK 64-Bit Server VM (build 25.161-b14, mixed mode)

# %%
# !clush -aB mkdir ~/Downloads
# !clush -aB "cd ~/Downloads && wget https://download.elastic.co/elasticsearch/elasticsearch/elasticsearch-1.7.3.noarch.rpm"
# Out:
# ---------------
# psnode[66-68] (3)
# ---------------
# mkdir: cannot create directory ‘/home/mapr/Downloads’: File exists
# clush: psnode[66-68] (3): exited with exit code 1
# ---------------
# psnode66
# ---------------
# --2019-01-23 03:32:25--  https://download.elastic.co/elasticsearch/elasticsearch/elasticsearch-1.7.3.noarch.rpm
# Resolving download.elastic.co (download.elastic.co)... 151.101.66.217, 151.101.130.217, 151.101.194.217, ...
# Connecting to download.elastic.co (download.elastic.co)|151.101.66.217|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27332787 (26M) [binary/octet-stream]
# Saving to: ‘elasticsearch-1.7.3.noarch.rpm’
#
#      0K .......... .......... .......... .......... ..........  0% 14.4M 2s
#     50K .......... .......... .......... .......... ..........  0% 14.2M 2s
#    100K .......... .......... .......... .......... ..........  0% 24.8M 2s
#    150K .......... .......... .......... .......... ..........  0% 16.2M 2s
# ...

# %%
# !sudo -S clush -aB rpm -ivh $HOME/Downloads/elasticsearch-1.7.3.noarch.rpm < $HOME/my_password_file
# Out:
# [sudo] password for mapr: ---------------
# psnode[66-68] (3)
# ---------------
# ...
# Preparing...                          ########################################
# Creating elasticsearch group... OK
# Creating elasticsearch user... OK
# Updating / installing...
# elasticsearch-1.7.3-1                 ########################################
# ### NOT starting on installation, please execute the following statements to configure elasticsearch service to start automatically using systemd
#  sudo systemctl daemon-reload
#  sudo systemctl enable elasticsearch.service
# ### You can start elasticsearch service by executing
#  sudo systemctl start elasticsearch.service
